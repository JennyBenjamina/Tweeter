# %%
from TweetScraper import TweetScraper
from utility import text_extractor, to_single_line, to_df, count

# %%
tweetie = TweetScraper()

# %%
t = tweetie.get_tweets('tennis')

# %%
x = text_extractor(t)
y = to_single_line(x)

print(y)
# Out:
# ["Some in the Russian sport world have also come out against Putin's invasion of Ukraine, including footballer Fedor… https://t.co/CGntYeknlt", 'Johnson’s six point plan is to offer Putin 1. A peerage.2. Rename the Tory Party after him.3. A tennis match.4.… https://t.co/cDMlgCwV83', 'Record-breaking Ukrainian 97-year-old amateur tennis player Leonid Stanislavskyi has decided to stay on in Kharkiv… https://t.co/5kxCkkGI03', "Twelve of Michigan's 27 sports have won a Big Ten title in the last 12 months:-Football-Men's basketball-Women's… https://t.co/71U6KEwWPV", "At 97, the world's oldest tennis player has decided to stay put in Ukraine's war zone https://t.co/0vrgow8QUu https://t.co/H2MAUHdjG8", 'Excited to work with @VodafoneUK as their ambassador for Play Your Way to Wimbledon. Through this tournament, we’ll… https://t.co/27bgfnxXRD', '3. A tennis court atop the Burj al Arab hotel in Dubai. https://t.co/FLwZwOstA5', "Four months after 97-year-old amateur tennis player Leonid Stanis
# ...

# %%
df = to_df(y)
print(df)
# Out:
#     tweets                                               text
# 0        1  Some in the Russian sport world have also come...
# 1        2  Johnson’s six point plan is to offer Putin 1. ...
# 2        3  Record-breaking Ukrainian 97-year-old amateur ...
# 3        4  Twelve of Michigan's 27 sports have won a Big ...
# 4        5  At 97, the world's oldest tennis player has de...
# 5        6  Excited to work with @VodafoneUK as their amba...
# 6        7  3. A tennis court atop the Burj al Arab hotel ...
# 7        8  Four months after 97-year-old amateur tennis p...
# 8        9  Thanks @TheRealPCB for inviting Pakistan Davis...
# 9       10       My guarding angel .. https://t.co/2m56KvgSRT
# 10      11  Gazing at those mountains ⛰Hello again tennis ...
# 11      12  The world's oldest tennis player, 97 years old...
# 12      13  Champions in the making; table tennis training...
# 13      14  39. The All Iowa Lawn Tennis Club in Charles C...
# ...

# %%
tweetie.find_users_tweets()
# Out:
# dict_keys(['_api', '_json', 'id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'follow_request_sent', 'notifications', 'translator_type', 'withheld_in_countries'])
# 0 2022-03-07 20:44:40+00:00
# 1 2022-03-07 07:49:42+00:00
# 2 2022-03-07 07:08:48+00:00
# 3 2022-03-07 00:51:04+00:00
# ...

# %%
tweetie.get_my_tweets()
# Out:
# dict_keys(['_api', '_json', 'created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'source', 'source_url', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'author', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'quoted_status_id', 'quoted_status_id_str', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'possibly_sensitive_appealable', 'lang'])
# ([[datetime.datetime(2022, 3, 7, 21, 4, 10, tzinfo=datetime.timezone.utc),
#    'safiyanoble',
#    'RT @salvilake: It really was a great conversation. Hope you check out the episode. #AbolitionX https://t.co/mFFoV5Uuv6',
#    1],
#   [datetime.datetime(2022, 3, 7, 21, 3, 59, tzinfo=datetime.timezone.utc),
#    'safiyanoble',
#    'RT @JohnBKing: I just became the first U.S. Secretary of Education to call on President Biden to unilaterally cancel student loan debt. Can…',
# ...

# %%
tweetie.find_users()
# Out:
# dict_keys(['_api', '_json', 'id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'follow_request_sent', 'notifications', 'translator_type', 'withheld_in_countries'])
# ...

# %%
test()
# Out:
# from utility
# 0
